# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Lane: Content Refresh Prioritization
#
# I chose the Content Refresh Prioritization lane because the dataset contains information about page performance, search visibility, engagement, freshness, and content characteristics. Instead of updating every page, this project aims to identify which pages should be refreshed first so that time and resources can be focused where they are likely to have the greatest impact.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### The question: decision, action, cost of a wrong call
#
# **Research Question:** Which content pages should be prioritized for refresh to improve future search performance?
#
# **Decision:** Decide which pages should be refreshed first.
#
# **Action:** The content or SEO team updates the highest-priority pages before others.
#
# **Cost of a Wrong Call:** Refreshing the wrong pages wastes time and effort, while pages with greater potential may continue to lose traffic and visibility.
#
# **Why this matters:** The dataset includes many features such as impressions, clicks, CTR, engagement rate, search volume, competition, and average position. Considering these together can help make better content refresh decisions than relying on a single metric.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# A quick analysis of the starter dataset shows:
#
# - The dataset contains **30,000 rows** and **44 columns**.
# - The **average impressions over the last 90 days** are **5,200.37**.
# - The **median impressions (90d)** are **731**, while the **median clicks (90d)** are only **1**.
#
# These numbers suggest that content performance varies greatly across articles, making it worthwhile to investigate which characteristics are associated with higher search visibility and engagement.

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Median impressions (90d):", df["impressions_90d"].median())
print("Median clicks (90d):", df["clicks_90d"].median())
# Out:
# Rows: 30000
# Columns: 44
# Average impressions (90d): 5200.37
# Median impressions (90d): 731.0
# Median clicks (90d): 1.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful words: what I can and can't claim
#
# This project provides decision-support based on patterns found in historical data. It can help identify which content pages are good candidates for a refresh, but it cannot guarantee that refreshing a page will improve its search ranking or traffic. The results show associations rather than cause-and-effect, so the recommendations should be reviewed alongside human judgment before making decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
